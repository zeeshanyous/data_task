# %%
import pandas as pd 
from datetime import datetime
from pymongo import MongoClient

# %%
employee_df = pd.read_csv('employee_details.csv')

# Read data from department_details.csv
department_df = pd.read_csv('department_details.csv')

# %%
employee_df.head(4)
# Out:
#   EmployeeID FirstName    LastName     BirthDate     Department  Salary
# 0   E001       Alice       White      1990-06-12         D001     55000
# 1   E002         Bob       Brown      1988-01-03   D002           90000
# 2   E003        Carol      Grey       1995-07-15   D003           47000
# 3   E004        David      Black      1992-09-23          D004    75000

# %%
employee_df.columns = employee_df.columns.str.strip()
department_df.columns = department_df.columns.str.strip()

# %%
# Clean up department names in both dataframes
employee_df['Department'] = employee_df['Department'].str.strip()
employee_df['Department'] = employee_df['Department'].str.replace('\s+', ' ', regex=True)

# %%
# Print unique values in the 'Department' column in both dataframes
print("Unique values in employee_df['Department']:", employee_df['Department'].unique())
print("Unique values in department_df['Department']:", department_df['Department'].unique())

merged_df = pd.merge(employee_df, department_df, left_on='Department', right_on='DepartmentID', how='inner')

merged_df.head()
# Out:
# Unique values in employee_df['Department']: ['D001' 'D002' 'D003' 'D004' '-Invalid-']
# Unique values in department_df['Department']: [' Finance' ' IT' ' HR' ' Marketing']
#   EmployeeID FirstName        LastName   BirthDate Department_x  Salary  \
# 0   E001       Alice         White      1990-06-12         D001   55000
# 1   E006        Frank        Turner     1980-11-21         D001   85000
# 2   E009          Ian        Ross       1996-05-27         D001  110000
# 3   E014         Carla     342 Jimenez  1975-03-03         D001   39400
# 4   E017        (Inna)         Romanov  1988-02-01         D001  102000
#
#   DepartmentID Department_y
# 0         D001      Finance
# 1         D001      Finance
# 2         D001      Finance
# 3         D001      Finance
# 4         D001      Finance

# %%
# 1. Convert the `BirthDate` from the format `YYYY-MM-DD` to `DD/MM/YYYY`
merged_df['BirthDate'] = merged_df['BirthDate'].replace({'2999-19-18': '9999-01-01'})
merged_df['BirthDate'] = pd.to_datetime(merged_df['BirthDate'], errors='coerce')
merged_df = merged_df[merged_df['BirthDate'].notnull()]

# %%
# Clean 'FirstName' and 'LastName', remove leading/trailing spaces and commas/periods

merged_df['FirstName'] = merged_df['FirstName'].str.replace('[,.* "=^;$@]', '', regex=True).str.strip()
merged_df['LastName'] = merged_df['LastName'].str.replace('[,.* "=^;$@]', '', regex=True).str.strip()

merged_df['FullName'] = merged_df['FirstName'] + ' ' + merged_df['LastName']

merged_df.head(4)
# Out:
#   EmployeeID FirstName    LastName  BirthDate Department_x  Salary  \
# 0   E001         Alice       White 1990-06-12         D001   55000
# 1   E006         Frank      Turner 1980-11-21         D001   85000
# 2   E009           Ian        Ross 1996-05-27         D001  110000
# 3   E014         Carla  342Jimenez 1975-03-03         D001   39400
#
#   DepartmentID Department_y          FullName
# 0         D001      Finance       Alice White
# 1         D001      Finance      Frank Turner
# 2         D001      Finance          Ian Ross
# 3         D001      Finance  Carla 342Jimenez

# %%
 # Calculate age based on reference date Jan 1st, 2024
reference_date = datetime(2024, 1, 1)
merged_df['Age'] = (reference_date.year - merged_df['BirthDate'].dt.year)

# %%
bins = [0, 50000, 100000, float('inf')]
labels = ['A', 'B', 'C']
merged_df['SalaryBucket'] = pd.cut(merged_df['Salary'], bins=bins, labels=labels, right=False)

# %%
merged_df.drop(['FirstName', 'LastName', 'BirthDate'], axis=1, inplace=True)

# %%
merged_df.head(4)
# Out:
#   EmployeeID Department_x  Salary DepartmentID Department_y          FullName  \
# 0   E001             D001   55000         D001      Finance       Alice White
# 1   E006             D001   85000         D001      Finance      Frank Turner
# 2   E009             D001  110000         D001      Finance          Ian Ross
# 3   E014             D001   39400         D001      Finance  Carla 342Jimenez
#
#    Age SalaryBucket
# 0   34            B
# 1   44            B
# 2   28            C
# 3   49            A

# %%
mongodb_uri = "mongodb://admin:password@localhost:27017/"
database_name = "assgin_data"
collection_name = "mycollection"

# Convert DataFrame to a list of dictionaries
data_to_insert = merged_df.to_dict(orient='records')

# Connect to MongoDB
client = MongoClient(mongodb_uri)
db = client[database_name]
collection = db[collection_name]

# Insert data into MongoDB collection
collection.insert_many(data_to_insert)

# Close the MongoDB connection
client.close()

print("Data inserted into MongoDB successfully.")
# Out:
# Data inserted into MongoDB successfully.

# %%
mongodb_uri = "mongodb://admin:password@localhost:27017/"
database_name = "assgin_data"
collection_name = "mycollection"


# Connect to MongoDB
client = MongoClient(mongodb_uri)
db = client[database_name]
collection = db[collection_name]


# Retrieve all documents from the collection
cursor = collection.find()
data_list = list(cursor)
# Print the retrieved documents
# for document in cursor:
#     print(document)

data_list
# Out:
# [{'_id': ObjectId('6592918a3ef23a94deff5d73'),
#   'EmployeeID': 'E001    ',
#   'Department_x': 'D001',
#   'Salary': 55000,
#   'DepartmentID': 'D001',
#   'Department_y': ' Finance',
#   'FullName': 'Alice White',
#   'Age': 34,
#   'SalaryBucket': 'B'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d74'),
#   'EmployeeID': 'E006    ',
#   'Department_x': 'D001',
#   'Salary': 85000,
#   'DepartmentID': 'D001',
#   'Department_y': ' Finance',
#   'FullName': 'Frank Turner',
#   'Age': 44,
#   'SalaryBucket': 'B'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d75'),
#   'EmployeeID': 'E009    ',
#   'Department_x': 'D001',
#   'Salary': 110000,
#   'DepartmentID': 'D001',
#   'Department_y': ' Finance',
#   'FullName': 'Ian Ross',
#   'Age': 28,
#   'SalaryBucket': 'C'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d76'),
#   'EmployeeID': 'E014    ',
#   'Department_x': 'D001',
#   'Salary': 39400,
#   'DepartmentID': 'D001',
#   'Department_y': ' Finance',
#   'FullName': 'Carla 342Jimenez',
#   'Age': 49,
#   'SalaryBucket': 'A'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d77'),
#   'EmployeeID': 'E017    ',
#   'Department_x': 'D001',
#   'Salary': 102000,
#   'DepartmentID': 'D001',
#   'Department_y': ' Finance',
#   'FullName': '(Inna) Romanov',
#   'Age': 36,
#   'SalaryBucket': 'C'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d78'),
#   'EmployeeID': 'E022    ',
#   'Department_x': 'D001',
#   'Salary': 180000,
#   'DepartmentID': 'D001',
#   'Department_y': ' Finance',
#   'FullName': 'Bell Smith',
#   'Age': 55,
#   'SalaryBucket': 'C'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d79'),
#   'EmployeeID': 'E027    ',
#   'Department_x': 'D001',
#   'Salary': 48000,
#   'DepartmentID': 'D001',
#   'Department_y': ' Finance',
#   'FullName': "Kelly O'Connel",
#   'Age': 14,
#   'SalaryBucket': 'A'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d7a'),
#   'EmployeeID': 'E032    ',
#   'Department_x': 'D001',
#   'Salary': 155000,
#   'DepartmentID': 'D001',
#   'Department_y': ' Finance',
#   'FullName': 'Travis Rumbold',
#   'Age': 37,
#   'SalaryBucket': 'C'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d7b'),
#   'EmployeeID': 'E036    ',
#   'Department_x': 'D001',
#   'Salary': 82000,
#   'DepartmentID': 'D001',
#   'Department_y': ' Finance',
#   'FullName': 'Olivia Ab01Sila',
#   'Age': 45,
#   'SalaryBucket': 'B'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d7c'),
#   'EmployeeID': 'E040    ',
#   'Department_x': 'D001',
#   'Salary': 97000,
#   'DepartmentID': 'D001',
#   'Department_y': ' Finance',
#   'FullName': 'Szilvia FrncisHall',
#   'Age': 27,
#   'SalaryBucket': 'B'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d7d'),
#   'EmployeeID': 'E044    ',
#   'Department_x': 'D001',
#   'Salary': 47000,
#   'DepartmentID': 'D001',
#   'Department_y': ' Finance',
#   'FullName': 'Gabriel Lakey',
#   'Age': 26,
#   'SalaryBucket': 'A'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d7e'),
#   'EmployeeID': 'E002    ',
#   'Department_x': 'D002',
#   'Salary': 90000,
#   'DepartmentID': 'D002',
#   'Department_y': ' IT',
#   'FullName': 'Bob Brown',
#   'Age': 36,
#   'SalaryBucket': 'B'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d7f'),
#   'EmployeeID': 'E005    ',
#   'Department_x': 'D002',
#   'Salary': 125000,
#   'DepartmentID': 'D002',
#   'Department_y': ' IT',
#   'FullName': 'Eve Green',
#   'Age': 39,
#   'SalaryBucket': 'C'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d80'),
#   'EmployeeID': 'E010    ',
#   'Department_x': 'D002',
#   'Salary': 70000,
#   'DepartmentID': 'D002',
#   'Department_y': ' IT',
#   'FullName': 'John Bishop',
#   'Age': 27,
#   'SalaryBucket': 'B'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d81'),
#   'EmployeeID': 'E011    ',
#   'Department_x': 'D002',
#   'Salary': 100000,
#   'DepartmentID': 'D002',
#   'Department_y': ' IT',
#   'FullName': 'Ada LLovelace',
#   'Age': 221,
#   'SalaryBucket': 'C'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d82'),
#   'EmployeeID': 'E012    ',
#   'Department_x': 'D002',
#   'Salary': 87500,
#   'DepartmentID': 'D002',
#   'Department_y': ' IT',
#   'FullName': 'AmyC Appleseed',
#   'Age': 48,
#   'SalaryBucket': 'B'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d83'),
#   'EmployeeID': 'E016    ',
#   'Department_x': 'D002',
#   'Salary': 75000,
#   'DepartmentID': 'D002',
#   'Department_y': ' IT',
#   'FullName': 'EllieJ McException',
#   'Age': 1,
#   'SalaryBucket': 'B'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d84'),
#   'EmployeeID': 'E021    ',
#   'Department_x': 'D002',
#   'Salary': 30000,
#   'DepartmentID': 'D002',
#   'Department_y': ' IT',
#   'FullName': 'Angela Williams',
#   'Age': 6,
#   'SalaryBucket': 'A'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d85'),
#   'EmployeeID': 'E025    ',
#   'Department_x': 'D002',
#   'Salary': 150075,
#   'DepartmentID': 'D002',
#   'Department_y': ' IT',
#   'FullName': 'Zayd Edris',
#   'Age': 46,
#   'SalaryBucket': 'C'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d86'),
#   'EmployeeID': 'E029    ',
#   'Department_x': 'D002',
#   'Salary': 75000,
#   'DepartmentID': 'D002',
#   'Department_y': ' IT',
#   'FullName': 'NeilQ Quintz',
#   'Age': 52,
#   'SalaryBucket': 'B'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d87'),
#   'EmployeeID': 'E031    ',
#   'Department_x': 'D002',
#   'Salary': 71000,
#   'DepartmentID': 'D002',
#   'Department_y': ' IT',
#   'FullName': 'Susan _Doe',
#   'Age': 43,
#   'SalaryBucket': 'B'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d88'),
#   'EmployeeID': 'E035    ',
#   'Department_x': 'D002',
#   'Salary': 127000,
#   'DepartmentID': 'D002',
#   'Department_y': ' IT',
#   'FullName': 'Nic_ Wilson',
#   'Age': 22,
#   'SalaryBucket': 'C'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d89'),
#   'EmployeeID': 'E039    ',
#   'Department_x': 'D002',
#   'Salary': 88000,
#   'DepartmentID': 'D002',
#   'Department_y': ' IT',
#   'FullName': 'RenéA RégisReed',
#   'Age': 29,
#   'SalaryBucket': 'B'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d8a'),
#   'EmployeeID': 'E046    ',
#   'Department_x': 'D002',
#   'Salary': 70000,
#   'DepartmentID': 'D002',
#   'Department_y': ' IT',
#   'FullName': 'IanS Kimball',
#   'Age': 53,
#   'SalaryBucket': 'B'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d8b'),
#   'EmployeeID': 'E003    ',
#   'Department_x': 'D003',
#   'Salary': 47000,
#   'DepartmentID': 'D003',
#   'Department_y': ' HR',
#   'FullName': 'Carol Grey',
#   'Age': 29,
#   'SalaryBucket': 'A'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d8c'),
#   'EmployeeID': 'E007    ',
#   'Department_x': 'D003',
#   'Salary': 62000,
#   'DepartmentID': 'D003',
#   'Department_y': ' HR',
#   'FullName': 'Grace Harper',
#   'Age': 31,
#   'SalaryBucket': 'B'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d8d'),
#   'EmployeeID': 'E015    ',
#   'Department_x': 'D003',
#   'Salary': 10000,
#   'DepartmentID': 'D003',
#   'Department_y': ' HR',
#   'FullName': '007Dena Smith-Tracy',
#   'Age': 44,
#   'SalaryBucket': 'A'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d8e'),
#   'EmployeeID': 'E018    ',
#   'Department_x': 'D003',
#   'Salary': 49999,
#   'DepartmentID': 'D003',
#   'Department_y': ' HR',
#   'FullName': 'Liska -diana',
#   'Age': 33,
#   'SalaryBucket': 'A'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d8f'),
#   'EmployeeID': 'E024    ',
#   'Department_x': 'D003',
#   'Salary': 20000,
#   'DepartmentID': 'D003',
#   'Department_y': ' HR',
#   'FullName': 'D\\nDora Delgadooo',
#   'Age': 24,
#   'SalaryBucket': 'A'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d90'),
#   'EmployeeID': 'E026    ',
#   'Department_x': 'D003',
#   'Salary': 45000,
#   'DepartmentID': 'D003',
#   'Department_y': ' HR',
#   'FullName': 'Tina McTwitter',
#   'Age': 34,
#   'SalaryBucket': 'A'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d91'),
#   'EmployeeID': 'E034    ',
#   'Department_x': 'D003',
#   'Salary': 60000,
#   'DepartmentID': 'D003',
#   'Department_y': ' HR',
#   'FullName': 'Minerva Torres',
#   'Age': 23,
#   'SalaryBucket': 'B'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d92'),
#   'EmployeeID': 'E037    ',
#   'Department_x': 'D003',
#   'Salary': 61000,
#   'DepartmentID': 'D003',
#   'Department_y': ' HR',
#   'FullName': 'Padma Patil',
#   'Age': 31,
#   'SalaryBucket': 'B'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d93'),
#   'EmployeeID': 'E041    ',
#   'Department_x': 'D003',
#   'Salary': 57000,
#   'DepartmentID': 'D003',
#   'Department_y': ' HR',
#   'FullName': 'AndreaS Val043_y',
#   'Age': 30,
#   'SalaryBucket': 'B'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d94'),
#   'EmployeeID': 'E045    ',
#   'Department_x': 'D003',
#   'Salary': 64000,
#   'DepartmentID': 'D003',
#   'Department_y': ' HR',
#   'FullName': 'Héctór Espinsa',
#   'Age': 39,
#   'SalaryBucket': 'B'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d95'),
#   'EmployeeID': 'E004    ',
#   'Department_x': 'D004',
#   'Salary': 75000,
#   'DepartmentID': 'D004',
#   'Department_y': ' Marketing',
#   'FullName': 'David Black',
#   'Age': 32,
#   'SalaryBucket': 'B'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d96'),
#   'EmployeeID': 'E008    ',
#   'Department_x': 'D004',
#   'Salary': 43000,
#   'DepartmentID': 'D004',
#   'Department_y': ' Marketing',
#   'FullName': 'Holly Norman',
#   'Age': 25,
#   'SalaryBucket': 'A'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d97'),
#   'EmployeeID': 'E013    ',
#   'Department_x': 'D004',
#   'Salary': 200150,
#   'DepartmentID': 'D004',
#   'Department_y': ' Marketing',
#   'FullName': 'Bao Nguyen',
#   'Age': 19,
#   'SalaryBucket': 'C'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d98'),
#   'EmployeeID': 'E019    ',
#   'Department_x': 'D004',
#   'Salary': 100000,
#   'DepartmentID': 'D004',
#   'Department_y': ' Marketing',
#   'FullName': 'Mario Antonio',
#   'Age': 39,
#   'SalaryBucket': 'C'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d99'),
#   'EmployeeID': 'E023    ',
#   'Department_x': 'D004',
#   'Salary': 99999,
#   'DepartmentID': 'D004',
#   'Department_y': ' Marketing',
#   'FullName': 'Cory Thompson',
#   'Age': 35,
#   'SalaryBucket': 'B'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d9a'),
#   'EmployeeID': 'E028    ',
#   'Department_x': 'D004',
#   'Salary': 98000,
#   'DepartmentID': 'D004',
#   'Department_y': ' Marketing',
#   'FullName': 'Marek Swobodzki',
#   'Age': 34,
#   'SalaryBucket': 'B'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d9b'),
#   'EmployeeID': 'E033    ',
#   'Department_x': 'D004',
#   'Salary': 51000,
#   'DepartmentID': 'D004',
#   'Department_y': ' Marketing',
#   'FullName': 'Lvi Marks',
#   'Age': 30,
#   'SalaryBucket': 'B'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d9c'),
#   'EmployeeID': 'E038    ',
#   'Department_x': 'D004',
#   'Salary': 43000,
#   'DepartmentID': 'D004',
#   'Department_y': ' Marketing',
#   'FullName': 'Ñelly García',
#   'Age': 20,
#   'SalaryBucket': 'A'},
#  {'_id': ObjectId('6592918a3ef23a94deff5d9d'),
#   'EmployeeID': 'E047    ',
#   'Department_x': 'D004',
#   'Salary': 5000,
#   'DepartmentID': 'D004',
#   'Department_y': ' Marketing',
#   'FullName': 'Jack Slater',
#   'Age': 39,
#   'SalaryBucket': 'A'}]

# %%
import json 
with open("output.json", 'w') as json_file:
        json.dump(data_list, json_file, indent=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[311], line 3
#       1 import json
#       2 with open("output.json", 'w') as json_file:
# ----> 3         abc = json.loads(data_list)
#       4         json.dump(abc, json_file, indent=2)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/__init__.py:339, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337 else:
#     338     if not isinstance(s, (bytes, bytearray)):
# --> 339         raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     340                         f'not {s.__class__.__name__}')
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
#
# TypeError: the JSON object must be str, bytes or bytearray, not list
